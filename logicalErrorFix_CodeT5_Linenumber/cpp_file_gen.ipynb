# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/logicalErrorFix-2/
# Out:
# /content/drive/MyDrive/logicalErrorFix-2

# %%
from __future__ import absolute_import
import os
import sys
import bleu
import pickle
import torch
import json
import random
import logging
import argparse
import numpy as np
import copy
from io import open
from itertools import cycle
import torch.nn as nn
from model import Seq2Seq
from tqdm import tqdm, trange
from torch.utils.data import DataLoader, Dataset, SequentialSampler, RandomSampler,TensorDataset
from torch.utils.data.distributed import DistributedSampler
from transformers import (WEIGHTS_NAME, AdamW, get_linear_schedule_with_warmup,
                          RobertaConfig, RobertaModel, RobertaTokenizer)

from transformers import T5ForConditionalGeneration
MODEL_CLASSES = {'roberta': (RobertaConfig, RobertaModel, RobertaTokenizer),
                 'codeT5' : (None, T5ForConditionalGeneration, RobertaTokenizer)}

logging.basicConfig(format = '%(asctime)s - %(levelname)s - %(name)s -   %(message)s',
                    datefmt = '%m/%d/%Y %H:%M:%S',
                    level = logging.INFO)
logger = logging.getLogger(__name__)

class Example(object):
    """A single training/test example."""
    def __init__(self,
                 idx,
                 source,
                 target,
                 ):
        self.idx = idx
        self.source = source
        self.target = target

import pandas as pd
COLUMNS = ['Correct_code', 'Incorrect_code', 'Statement']

def read_examples(filename):
  """Read examples from filename for DeepFix style training Line stmt Line stmt Line stmt ..."""
  examples = []
  data = pd.read_csv(filename, sep='\t', header=[0]).drop(columns=COLUMNS[0])
  for idx, elem in data.iterrows():
    code = ' '.join(elem[COLUMNS[1]].split('||| '))[:-1].strip()
    stmt = elem[COLUMNS[2]].strip()

    examples.append(
      Example(
              idx = idx,
              source = code,
              target = stmt,
              )
    )
  return examples

class InputFeatures(object):
    """A single training/test features for a example."""
    def __init__(self,
                 example_id,
                 source_ids,
                 target_ids,
                 source_mask,
                 target_mask,

    ):
        self.example_id = example_id
        self.source_ids = source_ids
        self.target_ids = target_ids
        self.source_mask = source_mask
        self.target_mask = target_mask

# %%
train_examples = read_examples('./data/edit_distance/pair_code_edit_dist_train.txt')

# %%
print(train_examples[2].source)
# Out:
# 1 #include <bits/stdc++.h> 2 using namespace std; 3 int dx[] = {0, 1, 0, -1, -1, 1, 1, -1}; 4 int dy[] = {1, 0, -1, 0, -1, -1, 1, 1}; 5 int kx[] = {-2, -2, -1, 1, 2, 2, 1, -1}; 6 int ky[] = {-1, 1, 2, 2, 1, -1, -2, -2}; 7 inline long long gcd(long long a, long long b) { 8 a = fabs(a); 9 b = fabs(b); 10 while (b) { 11 a = a % b; 12 swap(a, b); 13 } 14 return a; 15 } 16 inline long long bigmod(long long a, long long p, long long m) { 17 long long res = 1 % m, x = a % m; 18 while (p) { 19 if (p & 1) res = (res * x) % m; 20 x = (x * x) % m; 21 p >>= 1; 22 } 23 return res; 24 } 25 struct DATA { 26 long long a, b; 27 }; 28 vector<DATA> arr; 29 set<long long> s; 30 int main() { 31 long long n; 32 scanf("%lld", &n); 33 for (int i = (int)(1); i <= (int)(n); i++) { 34 long long x, y; 35 scanf("%lld %lld", &x, &y); 36 arr.push_back({x, y}); 37 } 38 if (n == 1) { 39 cout << arr[0].a << endl; 40 exit(0); 41 } 42 for (int i = 2; i * i <= arr[0].a; i++) { 43 if (arr[0].a % i == 0) { 44 while (arr[0].a % i == 0) arr[0].a /= i; 45 s.insert(i); 46 s.insert(arr[0].a / i); 47 } 48 } 49 if (arr[0].a > 2) s.insert(arr[0].a); 50 for (int i = 2; i * i <= arr[0].b; i++) { 51 if (arr[0].b % i == 0) { 52 while (arr[0].b % i == 0) arr[0].b /= i; 53 s.insert(i); 54 s.insert(arr[0].b / i); 55 } 56 } 57 if (arr[0].b > 2) s.insert(arr[0].b); 58 for (set<long long>::iterator it = s.begin(); it != s.end(); it++) { 59 bool found = 1; 60 long long x = *it; 61 if (x == 0) continue; 62 for (int j = (int)(1); j <= (int)(arr.size() - 1); j++) { 63 long long val1 = arr[j].a; 64 long long val2 = arr[j].b; 65 if (val1 % x != 0 and val2 % x != 0) { 66 found = 0; 67 break; 68 } 69 } 70 if (found and x > 1) { 71 cout << x << endl; 72 exit(0); 73 } 74 } 75 cout << "-1" << endl; 76 return 0; 77 }

# %%
def process_code_examples(input_examples):
    def parse_and_continue_on_mismatch(code_str):
        code_dict = {}
        expected_line_number = 1
        parts = code_str.split()
        current_line = None
        for part in parts:
            if part.isdigit():
                line_number = int(part)
                if line_number == expected_line_number:
                    current_line = line_number
                    code_dict[current_line] = ""
                    expected_line_number += 1
                else:
                    code_dict[current_line] += part + " "
            else:
                if current_line is not None:
                    code_dict[current_line] += part + " "
        for line in code_dict:
            code_dict[line] = code_dict[line].strip()
        return code_dict

    def remove_line_numbers(source_dict):
        ret = []
        for _, v in source_dict.items():
            ret.append(v)
        return ' '.join(ret)

    def parse_single_line_to_dict(line_str):
        parts = line_str.split(' ', 1)
        line_number = parts[0]
        code = parts[1] if len(parts) > 1 else ""
        return {int(line_number): code}

    def update_values_from_dict(dict1, dict2):
        for key in dict1:
            if key in dict2:
                dict1[key] = dict2[key]
        return dict1

    source_code_dict = {}
    for i, example in enumerate(input_examples):
        source_code_dict[i] = parse_and_continue_on_mismatch(example.source)

    target_dict = {}
    for i, example in enumerate(input_examples):
        target_dict[i] = parse_single_line_to_dict(example.target)

    target_code_dict = {i: update_values_from_dict(copy.deepcopy(source_code_dict[i]), target_dict[i]) for i in range(len(target_dict))}

    input_code = {}
    for i in range(len(source_code_dict)):
        input_code[i] = {
            "source": remove_line_numbers(source_code_dict[i]),
            "target": remove_line_numbers(target_code_dict[i])
        }

    return input_code

# %%
import argparse

# 명령줄 인자를 직접 코드 내에서 설정
args = argparse.Namespace(
    model_type='codeT5',
    model_name_or_path='Salesforce/codet5-base',
    output_dir='model/cpp',
    load_model_path='path/to/trained/model',
    train_filename='./data/edit_distance/pair_code_edit_dist_train.txt',
    dev_filename='./data/edit_distance/pair_code_edit_dist_valid.txt',
    test_filename='./data/edit_distance/pair_code_edit_dist_test.txt',
    config_name='',
    tokenizer_name='',
    max_source_length=64,
    max_target_length=32,
    do_train=True,
    do_eval=True,
    do_test=True,
    do_lower_case=True,
    no_cuda=True,
    train_batch_size=8,
    eval_batch_size=8,
    gradient_accumulation_steps=1,
    learning_rate=5e-5,
    beam_size=10,
    weight_decay=0.0,
    adam_epsilon=1e-8,
    max_grad_norm=1.0,
    num_train_epochs=3.0,
    max_steps=-1,
    eval_steps=-1,
    train_steps=-1,
    warmup_steps=0,
    local_rank=-1,
    seed=42,
)

# 예제 사용
print(args.model_type)  # 출력: roberta
print(args.do_train)    # 출력: True
# Out:
# codeT5
# True

# %%
config_class, model_class, tokenizer_class = MODEL_CLASSES[args.model_type]
if config_class is not None:
    config = config_class.from_pretrained(args.config_name if args.config_name else args.model_name_or_path)
tokenizer = tokenizer_class.from_pretrained(args.tokenizer_name if args.tokenizer_name else args.model_name_or_path,do_lower_case=args.do_lower_case)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
def parse_and_continue_on_mismatch(code_str):
    code_dict = {}
    expected_line_number = 1
    parts = code_str.split()
    current_line = None
    for part in parts:
        if part.isdigit():
            line_number = int(part)
            if line_number == expected_line_number:
                current_line = line_number
                code_dict[current_line] = ""
                expected_line_number += 1
            else:
                code_dict[current_line] += part + " "
        else:
            if current_line is not None:
                code_dict[current_line] += part + " "
    for line in code_dict:
        code_dict[line] = code_dict[line].strip()
    return code_dict

# %%
code_dict = parse_and_continue_on_mismatch(train_examples[1].source)

# %%
import json
dictionary_print = json.dumps(code_dict, indent=4)
print(dictionary_print)
# Out:
# {
#     "1": "#include <bits/stdc++.h>",
#     "2": "#pragma comment(linker, \"/stack:200000000\")",
#     "3": "#pragma GCC optimize(\"Ofast\")",
#     "4": "#pragma GCC target(\"sse,sse2,sse3,ssse3,sse4,popcnt,abm,mmx,avx,tune=native\")",
#     "5": "using namespace std;",
#     "6": "inline long long rint() {",
#     "7": "long long x = 0, f = 1;",
#     "8": "char c = getchar();",
#     "9": "while (c < '0' || c > '9') {",
#     "10": "if (c == '-') f = -1;",
#     "11": "c = getchar();",
#     "12": "}",
#     "13": "while (c >= '0' && c <= '9') {",
#     "14": "x = x * 10 + c - '0';",
#     "15": "c = getchar();",
#     "16": "}",
#     "17": "return x * f;",
#     "18": "}",
#     "19": "long long gcd(long long a, long long b) { return (b) ? gcd(b, a % b) : a; }",
#     "20": "long long lcm(long long a, long long b) { return a / gcd(a, b) * b; }",
#     "21": "long long pow(long long a, long long b, long long q) {",
#     "22": "long long ans = 1;",
#     "23": "while (b) {",
#     "24": "if (b & 1) ans = ans * a % q;",
#     "25": "a = a * a % q;",
#     "26": "b >>= 1;",
#     "27": "}",
#     "28": "return ans;",
#     "29": "}",
#     "30": "const long long mod = 998244353;",
#     "31": "const long long N = 2e6 + 5;",
#     "32": "int main() {",
#     "33": "int n = rint();",
#     "34": "vector<int> a(n), b(n);",
#     "35": "for (int i = 0; i < n; i++) a[i] = rint(), b[i] = rint();",
#     "36": "vector<int> fac;",
#     "37": "for (int i = 2; i * i <= a[0]; i++) {",
#     "38": "if (a[0] % i == 0) {",
#     "39": "fac.push_back(i);",
#     "40": "while (a[0] % i == 0) a[0] /= i;",
#     "41": "}",
#     "42": "}",
#     "43": "if (b[0] != 1) fac.push_back(b[0]);",
#     "44": "for (int i = 2; i * i <= b[0]; i++) {",
#     "45": "if (b[0] % i == 0) {",
#     "46": "fac.push_back(i);",
#     "47": "while (b[0] % i == 0) b[0] /= i;",
#     "48": "}",
#     "49": "}",
#     "50": "if (b[0] != 1) fac.push_back(b[0]);",
#     "51": "sort((fac).begin(), (fac).end());",
#     "52": "fac.erase(unique((fac).begin(), (fac).end()), fac.end());",
#     "53": "for (int i = 1; i < n; i++) {",
#     "54": "int jb = 0;",
#     "55": "while (jb != fac.size()) {",
#     "56": "if (a[i] % fac[jb] == 0 || b[i] % fac[jb] == 0)",
#     "57": "jb++;",
#     "58": "else",
#     "59": "fac.erase(fac.begin() + jb);",
#     "60": "}",
#     "61": "}",
#     "62": "if (fac.size() == 0)",
#     "63": "cout << -1 << \"\\n\";",
#     "64": "else",
#     "65": "cout << fac[0] << \"\\n\";",
#     "66": "}"
# }

# %%
code_dict_list = []
for i in range(len(train_examples)):
    code_dict_list.append(parse_and_continue_on_mismatch(train_examples[i].source))

# %%
print(code_dict_list[0])
# Out:
# {1: '#include <bits/stdc++.h>', 2: 'using namespace std;', 3: 'int ara[500008];', 4: 'set<int> s;', 5: 'set<int>::iterator it;', 6: 'int n;', 7: 'void check(int num) {', 8: 'for (int i = 1; i < n; i++) {', 9: 'if (!(ara[i] % num == 0 || ara[n + i] % num == 0)) {', 10: 'return;', 11: '}', 12: '}', 13: 'cout << num << endl;', 14: 'exit(0);', 15: '}', 16: 'int primefactor(int num) {', 17: 'int i;', 18: 'for (i = 2; i <= num / i; i++) {', 19: 'bool flag = 0;', 20: 'while (num % i == 0) {', 21: 'num /= i;', 22: 'if (!flag) {', 23: 'check(i);', 24: '}', 25: 'flag = 1;', 26: '}', 27: '}', 28: 'if (num > i) {', 29: 'check(num);', 30: '}', 31: '}', 32: 'int main() {', 33: 'scanf("%d", &n);', 34: 'for (int i = 0; i < n; i++) {', 35: 'scanf("%d%d", &ara[i], &ara[n + i]);', 36: '}', 37: 'primefactor(ara[0]);', 38: 'primefactor(ara[n]);', 39: 'cout << "-1" << endl;', 40: 'return 0;', 41: '}'}

# %%
def parse_single_line_to_dict(line_str):
    parts = line_str.split(' ', 1)
    line_number = parts[0]
    code = parts[1] if len(parts) > 1 else ""

    return {int(line_number): code}

target_dict_list = []
for i in range(len(train_examples)):
    target_dict_list.append(parse_single_line_to_dict(train_examples[i].target))

# %%
import copy
target_code_dict_list = copy.deepcopy(code_dict_list)

# %%
def update_values_from_dict(dict1, dict2):
    for key in dict1:
        if key in dict2:
            dict1[key] = dict2[key]
    return dict1

# %%
for i in range(len(target_code_dict_list)):
    target_code_dict_list[i] = update_values_from_dict(target_code_dict_list[i], target_dict_list[i])

# %%
print(code_dict_list[58])
print(target_code_dict_list[58])
print(target_dict_list[58])
print(train_examples[58 ].target)
# Out:
# {1: '#include <bits/stdc++.h>', 2: 'using namespace std;', 3: 'int main() {', 4: 'string a, b;', 5: 'getline(cin, a);', 6: 'getline(cin, b);', 7: 'sort(a.begin(), a.end());', 8: 'int z = 0;', 9: 'int idx = 0;', 10: 'for (int i = 0; i < a.size(); i++) {', 11: "if (a[i] == '0')", 12: 'z++;', 13: 'else {', 14: 'idx = i;', 15: 'break;', 16: '}', 17: '}', 18: 'string res;', 19: 'if (idx != 0) {', 20: 'res.push_back(a[idx]);', 21: 'idx++;', 22: '}', 23: 'for (int i = 0; i < z; i++) {', 24: "res.push_back('0');", 25: '}', 26: 'for (int i = idx; i < a.size(); i++) res.push_back(a[i]);', 27: 'if (res == b)', 28: 'cout << "OK" << endl;', 29: 'else', 30: 'cout << "WRONG_ANSWER" << endl;', 31: 'return 0;', 32: '}'}
# {1: '#include <bits/stdc++.h>', 2: 'using namespace std;', 3: 'int main() {', 4: 'string a, b;', 5: 'getline(cin, a);', 6: 'getline(cin, b);', 7: 'sort(a.begin(), a.end());', 8: 'int z = 0;', 9: 'int idx = 0;', 10: 'for (int i = 0; i < a.size(); i++) {', 11: "if (a[i] == '0')", 12: 'z++;', 13: 'else {', 14: 'idx = i;', 15: 'break;', 16: '}', 17: '}', 18: 'string res;', 19: 'if (idx != 0) {', 20: 'res.push_back(a[idx]);', 21: 'idx++;', 22: 'for (int i = 0; i < z; i++) {', 23: 'for (int i = 0; i < z; i++) {', 24: "res.push_back('0');", 25: '}', 26: 'for (int i = idx; i < a.size(); i++) res.push_back(a[i]);', 27: 'if (res == b)', 28: 'cout << "OK" << endl;', 29: 'else', 30: 'cout << "WRONG_ANSWER" << endl;', 31: 'return 0;', 32: '}'}
# {22: 'for (int i = 0; i < z; i++) {'}
# 22 for (int i = 0; i < z; i++) {

# %%
for i in range(10):
    print(train_examples[i].target)
# Out:
# 28 if (num > 1) {
# 43 if (a[0] != 1) fac.push_back(a[0]);
# 49 if (arr[0].a > 1) s.insert(arr[0].a);
# 28 if (num >= i) {
# 38 printf("%lf\n", ans);
# 64 dfs(0);
# 64 dfs(0);
# 51 if (type[i] == 0)
# 38 sum[u] += (1 - p[v]);
# 62 sol += (dp[n - 1][curr][1] + dp[n - 1][curr][2]) % MOD;

# %%
target_line_numbers = []
for i in range(len(train_examples)):
    line_number = int(train_examples[i].target.split(' ', 1)[0])
    target_line_numbers.append(line_number)

# %%
print(len(target_line_numbers))
# Out:
# 56051

# %%
print(target_line_numbers[0:10])
# Out:
# [28, 43, 49, 28, 38, 64, 64, 51, 38, 62]

# %%
def find_main_function_bounds(index, code_dict):
    start_line = None
    end_line = None
    brace_count = 0

    for line_number, code_line in code_dict.items():
        if 'main' in code_line and start_line is None:
            start_line = int(line_number)

        if start_line is not None:
            brace_count += code_line.count('{') - code_line.count('}')
            if brace_count == 0 and start_line is not None:
                end_line = int(line_number)
                break

    if start_line is None or end_line is None:
        print(f'{index} line error - start line {start_line}, end_line {end_line}, brace_count {brace_count}')
        return [-1, -1]

    return [start_line, end_line]

# %%
main_loc_list = []
count = 0
Nan_list = []
for index, code_dict in enumerate(code_dict_list):
    temp = find_main_function_bounds(index, code_dict)
    if temp[0] == -1:
        count += 1
        Nan_list.append(index)
    main_loc_list.append(temp)
print(f'오류 code 개수 : {count}')
# Out:
# 4239 line error - start line 3, end_line None, brace_count 1
# 6332 line error - start line 17, end_line None, brace_count 1
# 7353 line error - start line 5, end_line None, brace_count 2
# 9277 line error - start line None, end_line None, brace_count 0
# 11504 line error - start line 4, end_line None, brace_count 1
# 12243 line error - start line 3, end_line None, brace_count 2
# 12645 line error - start line 6, end_line None, brace_count 1
# 12654 line error - start line 4, end_line None, brace_count 1
# 13882 line error - start line 4, end_line None, brace_count 1
# 14309 line error - start line 4, end_line None, brace_count 1
# 14792 line error - start line 2, end_line None, brace_count -1
# 14802 line error - start line 3, end_line None, brace_count 1
# 15250 line error - start line 32, end_line None, brace_count 1
# 15667 line error - start line 8, end_line None, brace_count 1
# 16519 line error - start line 3, end_line None, brace_count 1
# 17514 line error - start line 33, end_line None, brace_count 1
# 18841 line error - start line 3, end_line None, brace_count 1
# 18852 line error - start line 5, end_line None, brace_count -1
# 19781 line error - start line 4, end_line None, brace_count 1
# 20579 line error - start line 4, end_line None, brace_count 1
# 21358 line error - start line 5, end_line None, brace_count 1
# 21832 line error - start line 4, end_line None, brace_count 1
# 21836 line error - start line 3, end_line None, brace_count 1
# 21868 line error - start line 75, end_line None, brace_count 1
# 24223 line error - start line 5, end_line None, brace_count 1
# 25172 line error - start line 2, end_line None, brace_count 1
# 25513 line error - start line 5, end_line None, brace_count 2
# 25514 line error - start line 4, end_line None, brace_count 2
# 25590 line error - start line 4, end_line None, brace_count 1
# 25596 line error - start line 22, end_line None, brace_count 1
# 25695 line error - start line 3, end_line None, brace_count 1
# 25975 line error - start line 3, end_line None, brace_count 1
# 27185 line error - start line 47, end_line None, brace_count 1
# 27499 line error - start line 2, end_line None, brace_count 1
# 27501 line error - start line 67, end_line None, brace_count 1
# 27502 line error - start line 3, end_line None, brace_count 1
# 27586 line error - start line 5, end_line None, brace_count 1
# 27674 line error - start line 4, end_line None, brace_count 1
# 27682 line error - start line 7, end_line None, brace_count 1
# 27684 line error - start line 40, end_line None, brace_count 1
# 27691 line error - start line 3, end_line None, brace_count 1
# 28112 line error - start line 3, end_line None, brace_count 1
# 28118 line error - start line 3, end_line None, brace_count 1
# 28491 line error - start line 3, end_line None, brace_count 1
# 29348 line error - start line 4, end_line None, brace_count 1
# 30276 line error - start line 19, end_line None, brace_count 1
# 30745 line error - start line 3, end_line None, brace_count 1
# 31143 line error - start line 3, end_line None, brace_count 1
# 31146 line error - start line 5, end_line None, brace_count 1
# 31617 line error - start line 21, end_line None, brace_count 1
# 32401 line error - start line 14, end_line None, brace_count 1
# 34706 line error - start line 6, end_line None, brace_count 1
# 35099 line error - start line None, end_line None, brace_count 0
# 35117 line error - start line 4, end_line None, brace_count 1
# 36380 line error - start line 4, end_line None, brace_count 1
# 38336 line error - start line 4, end_line None, brace_count 1
# 39710 line error - start line 6, end_line None, brace_count 1
# 40603 line error - start line 4, end_line None, brace_count 1
# 40821 line error - start line 4, end_line None, brace_count 1
# 40856 line error - start line 3, end_line None, brace_count 1
# 42571 line error - start line 69, end_line None, brace_count 1
# 43479 line error - start line 29, end_line None, brace_count 1
# 44944 line error - start line 10, end_line None, brace_count 1
# 46842 line error - start line 20, end_line None, brace_count 1
# 47626 line error - start line 9, end_line None, brace_count 1
# 49187 line error - start line 9, end_line None, brace_count 1
# 49624 line error - start line 4, end_line None, brace_count 1
# 50030 line error - start line 21, end_line None, brace_count 1
# 51718 line error - start line 3, end_line None, brace_count 1
# 51746 line error - start line 42, end_line None, brace_count 1
# 52135 line error - start line 8, end_line None, brace_count 1
# 53045 line error - start line 3, end_line None, brace_count 1
# 54367 line error - start line 55, end_line None, brace_count 1
# 54368 line error - start line 55, end_line None, brace_count 1
# 54548 line error - start line 59, end_line None, brace_count 1
# 54710 line error - start line 2, end_line None, brace_count 1
# 55153 line error - start line None, end_line None, brace_count 0
# 55155 line error - start line 3, end_line None, brace_count 1
# 오류 code 개수 : 78

# %%
print(Nan_list)
# Out:
# [4239, 6332, 7353, 9277, 11504, 12243, 12645, 12654, 13882, 14309, 14792, 14802, 15250, 15667, 16519, 17514, 18841, 18852, 19781, 20579, 21358, 21832, 21836, 21868, 24223, 25172, 25513, 25514, 25590, 25596, 25695, 25975, 27185, 27499, 27501, 27502, 27586, 27674, 27682, 27684, 27691, 28112, 28118, 28491, 29348, 30276, 30745, 31143, 31146, 31617, 32401, 34706, 35099, 35117, 36380, 38336, 39710, 40603, 40821, 40856, 42571, 43479, 44944, 46842, 47626, 49187, 49624, 50030, 51718, 51746, 52135, 53045, 54367, 54368, 54548, 54710, 55153, 55155]

# %%
Nan_list_modified = []
main_loc_list_modified = []
count = 0
Nan_list = []
for index, code_dict in enumerate(target_code_dict_list):
    temp = find_main_function_bounds(index, code_dict)
    if temp[0] == -1:
        count += 1
        Nan_list_modified.append(index)
    main_loc_list_modified.append(temp)
print(f'오류 code 개수 : {count}')
# Out:
# 58 line error - start line 3, end_line None, brace_count 2
# 78 line error - start line 3, end_line None, brace_count 1
# 155 line error - start line 8, end_line None, brace_count 1
# 250 line error - start line 3, end_line None, brace_count 1
# 252 line error - start line 17, end_line None, brace_count 1
# 314 line error - start line 3, end_line None, brace_count 2
# 448 line error - start line 6, end_line None, brace_count 1
# 873 line error - start line 3, end_line None, brace_count 1
# 2443 line error - start line 3, end_line None, brace_count 2
# 2465 line error - start line None, end_line None, brace_count 0
# 2603 line error - start line 4, end_line None, brace_count 1
# 2609 line error - start line 27, end_line None, brace_count 1
# 2611 line error - start line 8, end_line None, brace_count 1
# 2620 line error - start line 3, end_line None, brace_count 1
# 2746 line error - start line 24, end_line None, brace_count 1
# 2973 line error - start line 3, end_line None, brace_count 1
# 3034 line error - start line 6, end_line None, brace_count 1
# 3041 line error - start line 6, end_line None, brace_count 1
# 3465 line error - start line 46, end_line None, brace_count 1
# 3512 line error - start line 3, end_line None, brace_count 1
# 3745 line error - start line 16, end_line None, brace_count 1
# 3814 line error - start line None, end_line None, brace_count 0
# 3816 line error - start line None, end_line None, brace_count 0
# 3817 line error - start line None, end_line None, brace_count 0
# 3977 line error - start line 8, end_line None, brace_count 1
# 4040 line error - start line 17, end_line None, brace_count 1
# 4112 line error - start line 5, end_line None, brace_count 1
# 4196 line error - start line 39, end_line None, brace_count 1
# 4209 line error - start line None, end_line None, brace_count 0
# 4210 line error - start line None, end_line None, brace_count 0
# 4294 line error - start line 17, end_line None, brace_count 1
# 4371 line error - start line 7, end_line None, brace_count 1
# 4409 line error - start line 18, end_line None, brace_count 1
# 4413 line error - start line 39, end_line None, brace_count 1
# 4516 line error - start line 4, end_line None, brace_count 1
# 4525 line error - start line 4, end_line None, brace_count 1
# 4531 line error - start line 6, end_line None, brace_count 1
# 4584 line error - start line 19, end_line None, brace_count 1
# 4767 line error - start line 5, end_line None, brace_count 1
# 5085 line error - start line 5, end_line None, brace_count 2
# 5109 line error - start line 3, end_line None, brace_count 1
# 5150 line error - start line None, end_line None, brace_count 0
# 5167 line error - start line 4, end_line None, brace_count 1
# 5389 line error - start line 16, end_line None, brace_count 1
# 5543 line error - start line None, end_line None, brace_count 0
# 5575 line error - start line 7, end_line None, brace_count 1
# 5627 line error - start line 17, end_line None, brace_count 2
# 5762 line error - start line 12, end_line None, brace_count 1
# 5774 line error - start line 3, end_line None, brace_count 1
# 5775 line error - start line 8, end_line None, brace_count 1
# 5781 line error - start line 6, end_line None, brace_count 1
# 5785 line error - start line 3, end_line None, brace_count 1
# 5857 line error - start line 37, end_line None, brace_count 1
# 5910 line error - start line None, end_line None, brace_count 0
# 5928 line error - start line None, end_line None, brace_count 0
# 5973 line error - start line 6, end_line None, brace_count 1
# 6322 line error - start line None, end_line None, brace_count 0
# 6332 line error - start line 17, end_line None, brace_count 1
# 6337 line error - start line None, end_line None, brace_count 0
# 6393 line error - start line 2, end_line None, brace_count 1
# 6638 line error - start line 37, end_line None, brace_count 1
# 6780 line error - start line 41, end_line None, brace_count 1
# 6782 line error - start line 24, end_line None, brace_count 1
# 7007 line error - start line None, end_line None, brace_count 0
# 7008 line error - start line None, end_line None, brace_count 0
# 7009 line error - start line None, end_line None, brace_count 0
# 7013 line error - start line None, end_line None, brace_count 0
# 7014 line error - start line None, end_line None, brace_count 0
# 7021 line error - start line None, end_line None, brace_count 0
# 7022 line error - start line None, end_line None, brace_count 0
# 7023 line error - start line None, end_line None, brace_count 0
# 7024 line error - start line None, end_line None, brace_count 0
# 7025 line error - start line None, end_line None, brace_count 0
# 7028 line error - start line None, end_line None, brace_count 0
# 7032 line error - start line None, end_line None, brace_count 0
# 7053 line error - start line 44, end_line None, brace_count 1
# 7275 line error - start line 33, end_line None, brace_count 1
# 7312 line error - start line None, end_line None, brace_count 0
# 7317 line error - start line None, end_line None, brace_count 0
# 7324 line error - start line None, end_line None, brace_count 0
# 7342 line error - start line None, end_line None, brace_count 0
# 7353 line error - start line 5, end_line None, brace_count 2
# 7585 line error - start line 3, end_line None, brace_count 1
# 7617 line error - start line 3, end_line None, brace_count 1
# 7618 line error - start line 23, end_line None, brace_count 1
# 7694 line error - start line None, end_line None, brace_count 0
# 7705 line error - start line None, end_line None, brace_count 0
# 7706 line error - start line None, end_line None, brace_count 0
# 7708 line error - start line None, end_line None, brace_count 0
# 7714 line error - start line None, end_line None, brace_count 0
# 7724 line error - start line None, end_line None, brace_count 0
# 7726 line error - start line None, end_line None, brace_count 0
# 8001 line error - start line 31, end_line None, brace_count 1
# 8003 line error - start line 37, end_line None, brace_count 1
# 8078 line error - start line 3, end_line None, brace_count 1
# 8096 line error - start line None, end_line None, brace_count 0
# 8169 line error - start line 3, end_line None, brace_count 1
# 8506 line error - start line None, end_line None, brace_count 0
# 8534 line error - start line 6, end_line None, brace_count 1
# 8598 line error - start line 3, end_line None, brace_count 1
# 8620 line error - start line 17, end_line None, brace_count 1
# 8692 line error - start line 3, end_line None, brace_count 1
# 8805 line error - start line 20, end_line None, brace_count 1
# 8870 line error - start line 46, end_line None, brace_count 1
# 8895 line error - start line None, end_line None, brace_count 0
# 8896 line error - start line None, end_line None, brace_count 0
# 8901 line error - start line None, end_line None, brace_count 0
# 8934 line error - start line 3, end_line None, brace_count 1
# 8993 line error - start line 4, end_line None, brace_count 1
# 9079 line error - start line 6, end_line None, brace_count 1
# 9238 line error - start line 27, end_line None, brace_count 1
# 9264 line error - start line None, end_line None, brace_count 0
# 9265 line error - start line None, end_line None, brace_count 0
# 9279 line error - start line None, end_line None, brace_count 0
# 9342 line error - start line 5, end_line None, brace_count 1
# 9344 line error - start line 5, end_line None, brace_count 1
# 9373 line error - start line 19, end_line None, brace_count 1
# 9752 line error - start line 3, end_line None, brace_count 1
# 9766 line error - start line None, end_line None, brace_count 0
# 9767 line error - start line None, end_line None, brace_count 0
# 9769 line error - start line None, end_line None, brace_count 0
# 9770 line error - start line None, end_line None, brace_count 0
# 9771 line error - start line None, end_line None, brace_count 0
# 9772 line error - start line None, end_line None, brace_count 0
# 9779 line error - start line None, end_line None, brace_count 0
# 9805 line error - start line None, end_line None, brace_count 0
# 9863 line error - start line 5, end_line None, brace_count 1
# 9864 line error - start line 3, end_line None, brace_count 1
# 10078 line error - start line 2, end_line None, brace_count 1
# 10257 line error - start line 3, end_line None, brace_count 2
# 10318 line error - start line 7, end_line None, brace_count 1
# 10508 line error - start line 4, end_line None, brace_count 1
# 10540 line error - start line 21, end_line None, brace_count 1
# 10543 line error - start line 13, end_line None, brace_count 1
# 10770 line error - start line 29, end_line None, brace_count 1
# 10843 line error - start line 3, end_line None, brace_count 1
# 10882 line error - start line 5, end_line None, brace_count 1
# 10919 line error - start line 3, end_line None, brace_count 1
# 11032 line error - start line 15, end_line None, brace_count 1
# 11062 line error - start line None, end_line None, brace_count 0
# 11063 line error - start line None, end_line None, brace_count 0
# 11064 line error - start line None, end_line None, brace_count 0
# 11065 line error - start line None, end_line None, brace_count 0
# 11066 line error - start line None, end_line None, brace_count 0
# 11067 line error - start line None, end_line None, brace_count 0
# 11068 line error - start line None, end_line None, brace_count 0
# 11069 line error - start line None, end_line None, brace_count 0
# 11070 line error - start line None, end_line None, brace_count 0
# 11071 line error - start line None, end_line None, brace_count 0
# 11072 line error - start line None, end_line None, brace_count 0
# 11073 line error - start line None, end_line None, brace_count 0
# 11263 line error - start line 5, end_line None, brace_count 2
# 11314 line error - start line 16, end_line None, brace_count 1
# 11438 line error - start line 6, end_line None, brace_count 2
# 11472 line error - start line 3, end_line None, brace_count 1
# 11479 line error - start line None, end_line None, brace_count 0
# 11484 line error - start line None, end_line None, brace_count 0
# 11485 line error - start line None, end_line None, brace_count 0
# 11486 line error - start line None, end_line None, brace_count 0
# 11487 line error - start line None, end_line None, brace_count 0
# 11488 line error - start line None, end_line None, brace_count 0
# 11491 line error - start line None, end_line None, brace_count 0
# 11492 line error - start line None, end_line None, brace_count 0
# 11493 line error - start line None, end_line None, brace_count 0
# 11494 line error - start line None, end_line None, brace_count 0
# 11495 line error - start line None, end_line None, brace_count 0
# 11501 line error - start line None, end_line None, brace_count 0
# 11726 line error - start line 14, end_line None, brace_count 1
# 11727 line error - start line 3, end_line None, brace_count 1
# 11817 line error - start line None, end_line None, brace_count 0
# 11819 line error - start line None, end_line None, brace_count 0
# 11820 line error - start line None, end_line None, brace_count 0
# 12309 line error - start line 19, end_line None, brace_count 1
# 12320 line error - start line 22, end_line None, brace_count 1
# 12324 line error - start line 4, end_line None, brace_count 1
# 12547 line error - start line 16, end_line None, brace_count 1
# 12645 line error - start line 6, end_line None, brace_count 1
# 12650 line error - start line None, end_line None, brace_count 0
# 12726 line error - start line 5, end_line None, brace_count 1
# 12863 line error - start line 7, end_line None, brace_count 1
# 12891 line error - start line 5, end_line None, brace_count 1
# 13004 line error - start line None, end_line None, brace_count 0
# 13111 line error - start line 6, end_line None, brace_count 1
# 13127 line error - start line 11, end_line None, brace_count 1
# 13130 line error - start line 5, end_line None, brace_count 1
# 13389 line error - start line None, end_line None, brace_count 0
# 13429 line error - start line 6, end_line None, brace_count 1
# 13433 line error - start line 3, end_line None, brace_count 1
# 13434 line error - start line 3, end_line None, brace_count 1
# 13695 line error - start line 3, end_line None, brace_count 1
# 13812 line error - start line 4, end_line None, brace_count 1
# 13882 line error - start line 4, end_line None, brace_count 1
# 13888 line error - start line None, end_line None, brace_count 0
# 13890 line error - start line None, end_line None, brace_count 0
# 13893 line error - start line None, end_line None, brace_count 0
# 13894 line error - start line None, end_line None, brace_count 0
# 13921 line error - start line None, end_line None, brace_count 0
# 13927 line error - start line None, end_line None, brace_count 0
# 13981 line error - start line 3, end_line None, brace_count 1
# 13983 line error - start line 5, end_line None, brace_count 1
# 13985 line error - start line 6, end_line None, brace_count 1
# 13989 line error - start line 3, end_line None, brace_count 1
# 13991 line error - start line 29, end_line None, brace_count 1
# 13993 line error - start line 3, end_line None, brace_count 1
# 14156 line error - start line 3, end_line None, brace_count 1
# 14297 line error - start line None, end_line None, brace_count 0
# 14298 line error - start line None, end_line None, brace_count 0
# 14306 line error - start line None, end_line None, brace_count 0
# 14307 line error - start line None, end_line None, brace_count 0
# 14310 line error - start line None, end_line None, brace_count 0
# 14321 line error - start line None, end_line None, brace_count 0
# 14322 line error - start line None, end_line None, brace_count 0
# 14333 line error - start line None, end_line None, brace_count 0
# 14334 line error - start line None, end_line None, brace_count 0
# 14335 line error - start line None, end_line None, brace_count 0
# 14336 line error - start line None, end_line None, brace_count 0
# 14340 line error - start line None, end_line None, brace_count 0
# 14342 line error - start line None, end_line None, brace_count 0
# 14343 line error - start line None, end_line None, brace_count 0
# 14344 line error - start line None, end_line None, brace_count 0
# 14345 line error - start line None, end_line None, brace_count 0
# 14346 line error - start line None, end_line None, brace_count 0
# 14357 line error - start line 3, end_line None, brace_count 1
# 14376 line error - start line None, end_line None, brace_count 0
# 14377 line error - start line None, end_line None, brace_count 0
# 14380 line error - start line None, end_line None, brace_count 0
# 14381 line error - start line None, end_line None, brace_count 0
# 14382 line error - start line None, end_line None, brace_count 0
# 14383 line error - start line None, end_line None, brace_count 0
# 14384 line error - start line None, end_line None, brace_count 0
# 14385 line error - start line None, end_line None, brace_count 0
# 14761 line error - start line None, end_line None, brace_count 0
# 14762 line error - start line None, end_line None, brace_count 0
# 14763 line error - start line None, end_line None, brace_count 0
# 14778 line error - start line None, end_line None, brace_count 0
# 14785 line error - start line None, end_line None, brace_count 0
# 14788 line error - start line 3, end_line None, brace_count 1
# 14837 line error - start line 4, end_line None, brace_count 1
# 14959 line error - start line 29, end_line None, brace_count 1
# 14960 line error - start line 11, end_line None, brace_count 1
# 15000 line error - start line 29, end_line None, brace_count 1
# 15007 line error - start line 21, end_line None, brace_count 1
# 15190 line error - start line 18, end_line None, brace_count 1
# 15202 line error - start line 3, end_line None, brace_count 1
# 15206 line error - start line 3, end_line None, brace_count 1
# 15217 line error - start line None, end_line None, brace_count 0
# 15218 line error - start line None, end_line None, brace_count 0
# 15228 line error - start line None, end_line None, brace_count 0
# 15233 line error - start line None, end_line None, brace_count 0
# 15234 line error - start line None, end_line None, brace_count 0
# 15240 line error - start line None, end_line None, brace_count 0
# 15241 line error - start line None, end_line None, brace_count 0
# 15242 line error - start line None, end_line None, brace_count 0
# 15243 line error - start line None, end_line None, brace_count 0
# 15250 line error - start line 32, end_line None, brace_count 1
# 15292 line error - start line 51, end_line None, brace_count 1
# 15301 line error - start line 12, end_line None, brace_count 1
# 15377 line error - start line 26, end_line None, brace_count 1
# 15456 line error - start line 18, end_line None, brace_count 1
# 15499 line error - start line 4, end_line None, brace_count 1
# 15500 line error - start line 6, end_line None, brace_count 1
# 15547 line error - start line 35, end_line None, brace_count 1
# 15665 line error - start line None, end_line None, brace_count 0
# 15666 line error - start line None, end_line None, brace_count 0
# 15667 line error - start line 8, end_line None, brace_count 1
# 15867 line error - start line 3, end_line None, brace_count 1
# 15922 line error - start line 4, end_line None, brace_count 1
# 15935 line error - start line 13, end_line None, brace_count 1
# 15945 line error - start line 3, end_line None, brace_count 1
# 16075 line error - start line None, end_line None, brace_count 0
# 16080 line error - start line None, end_line None, brace_count 0
# 16117 line error - start line None, end_line None, brace_count 0
# 16137 line error - start line None, end_line None, brace_count 0
# 16138 line error - start line None, end_line None, brace_count 0
# 16161 line error - start line 4, end_line None, brace_count 1
# 16164 line error - start line 40, end_line None, brace_count 1
# 16180 line error - start line 3, end_line None, brace_count 1
# 16266 line error - start line 3, end_line None, brace_count 1
# 16270 line error - start line 3, end_line None, brace_count 1
# 16271 line error - start line 18, end_line None, brace_count 1
# 16344 line error - start line 3, end_line None, brace_count 1
# 16378 line error - start line 4, end_line None, brace_count 1
# 16416 line error - start line 3, end_line None, brace_count 1
# 16520 line error - start line None, end_line None, brace_count 0
# 16521 line error - start line None, end_line None, brace_count 0
# 16522 line error - start line None, end_line None, brace_count 0
# 16523 line error - start line None, end_line None, brace_count 0
# 16524 line error - start line None, end_line None, brace_count 0
# 16525 line error - start line None, end_line None, brace_count 0
# 16526 line error - start line None, end_line None, brace_count 0
# 16527 line error - start line None, end_line None, brace_count 0
# 16528 line error - start line None, end_line None, brace_count 0
# 16545 line error - start line None, end_line None, brace_count 0
# 16642 line error - start line 36, end_line None, brace_count 1
# 16644 line error - start line 30, end_line None, brace_count 1
# 16686 line error - start line 3, end_line None, brace_count 1
# 16690 line error - start line 8, end_line None, brace_count 1
# 16694 line error - start line 9, end_line None, brace_count 1
# 16696 line error - start line 10, end_line None, brace_count 1
# 16784 line error - start line 3, end_line None, brace_count 1
# 16809 line error - start line 38, end_line None, brace_count 1
# 16900 line error - start line 21, end_line None, brace_count 1
# 16948 line error - start line 3, end_line None, brace_count 1
# 16966 line error - start line 3, end_line None, brace_count 1
# 16974 line error - start line None, end_line None, brace_count 0
# 16975 line error - start line 4, end_line None, brace_count 1
# 16980 line error - start line None, end_line None, brace_count 0
# 16981 line error - start line 4, end_line None, brace_count 1
# 16984 line error - start line None, end_line None, brace_count 0
# 16985 line error - start line None, end_line None, brace_count 0
# 16986 line error - start line None, end_line None, brace_count 0
# 16987 line error - start line None, end_line None, brace_count 0
# 16988 line error - start line None, end_line None, brace_count 0
# 16989 line error - start line None, end_line None, brace_count 0
# 16990 line error - start line None, end_line None, brace_count 0
# 16991 line error - start line None, end_line None, brace_count 0
# 16992 line error - start line None, end_line None, brace_count 0
# 16993 line error - start line None, end_line None, brace_count 0
# 17004 line error - start line None, end_line None, brace_count 0
# 17005 line error - start line None, end_line None, brace_count 0
# 17006 line error - start line None, end_line None, brace_count 0
# 17007 line error - start line None, end_line None, brace_count 0
# 17008 line error - start line None, end_line None, brace_count 0
# 17009 line error - start line None, end_line None, brace_count 0
# 17010 line error - start line None, end_line None, brace_count 0
# 17011 line error - start line None, end_line None, brace_count 0
# 17029 line error - start line None, end_line None, brace_count 0
# 17084 line error - start line None, end_line None, brace_count 0
# 17092 line error - start line None, end_line None, brace_count 0
# 17093 line error - start line None, end_line None, brace_count 0
# 17094 line error - start line None, end_line None, brace_count 0
# 17095 line error - start line None, end_line None, brace_count 0
# 17096 line error - start line None, end_line None, brace_count 0
# 17097 line error - start line None, end_line None, brace_count 0
# 17098 line error - start line None, end_line None, brace_count 0
# 17099 line error - start line None, end_line None, brace_count 0
# 17100 line error - start line None, end_line None, brace_count 0
# 17101 line error - start line None, end_line None, brace_count 0
# 17102 line error - start line None, end_line None, brace_count 0
# 17103 line error - start line None, end_line None, brace_count 0
# 17269 line error - start line 48, end_line None, brace_count 1
# 17467 line error - start line None, end_line None, brace_count 0
# 17472 line error - start line None, end_line None, brace_count 0
# 17473 line error - start line None, end_line None, brace_count 0
# 17477 line error - start line None, end_line None, brace_count 0
# 17482 line error - start line None, end_line None, brace_count 0
# 17485 line error - start line 4, end_line None, brace_count 1
# 17487 line error - start line None, end_line None, brace_count 0
# 17493 line error - start line None, end_line None, brace_count 0
# 17501 line error - start line None, end_line None, brace_count 0
# 17502 line error - start line None, end_line None, brace_count 0
# 17514 line error - start line 33, end_line None, brace_count 1
# 17665 line error - start line 3, end_line None, brace_count 1
# 17804 line error - start line 3, end_line None, brace_count 1
# 17891 line error - start line None, end_line None, brace_count 0
# 17901 line error - start line None, end_line None, brace_count 0
# 17906 line error - start line None, end_line None, brace_count 0
# 17907 line error - start line None, end_line None, brace_count 0
# 17908 line error - start line None, end_line None, brace_count 0
# 17909 line error - start line None, end_line None, brace_count 0
# 17910 line error - start line None, end_line None, brace_count 0
# 17911 line error - start line None, end_line None, brace_count 0
# 17912 line error - start line None, end_line None, brace_count 0
# 17913 line error - start line None, end_line None, brace_count 0
# 18058 line error - start line 3, end_line None, brace_count 1
# 18176 line error - start line 7, end_line None, brace_count 1
# 18178 line error - start line 22, end_line None, brace_count 1
# 18251 line error - start line 3, end_line None, brace_count 1
# 18252 line error - start line 3, end_line None, brace_count 1
# 18253 line error - start line 3, end_line None, brace_count 1
# 18320 line error - start line None, end_line None, brace_count 0
# 18355 line error - start line 22, end_line None, brace_count 1
# 18419 line error - start line 4, end_line None, brace_count 1
# 18709 line error - start line 3, end_line None, brace_count 1
# 18859 line error - start line None, end_line None, brace_count 0
# 18861 line error - start line None, end_line None, brace_count 0
# 18862 line error - start line None, end_line None, brace_count 0
# 18905 line error - start line 4, end_line None, brace_count 1
# 18916 line error - start line 6, end_line None, brace_count 1
# 18932 line error - start line 9, end_line None, brace_count 1
# 18935 line error - start line 3, end_line None, brace_count 1
# 18958 line error - start line 3, end_line None, brace_count 1
# 18963 line error - start line 5, end_line None, brace_count 1
# 18988 line error - start line 7, end_line None, brace_count 1
# 19059 line error - start line 3, end_line None, brace_count 1
# 19316 line error - start line None, end_line None, brace_count 0
# 19317 line error - start line None, end_line None, brace_count 0
# 19318 line error - start line None, end_line None, brace_count 0
# 19321 line error - start line None, end_line None, brace_count 0
# 19324 line error - start line None, end_line None, brace_count 0
# 19325 line error - start line None, end_line None, brace_count 0
# 19328 line error - start line None, end_line None, brace_count 0
# 19333 line error - start line None, end_line None, brace_count 0
# 19336 line error - start line None, end_line None, brace_count 0
# 19337 line error - start line None, end_line None, brace_count 0
# 19338 line error - start line None, end_line None, brace_count 0
# 19339 line error - start line None, end_line None, brace_count 0
# 19340 line error - start line None, end_line None, brace_count 0
# 19360 line error - start line None, end_line None, brace_count 0
# 19361 line error - start line None, end_line None, brace_count 0
# 19362 line error - start line None, end_line None, brace_count 0
# 19363 line error - start line None, end_line None, brace_count 0
# 19364 line error - start line None, end_line None, brace_count 0
# 19365 line error - start line None, end_line None, brace_count 0
# 19366 line error - start line None, end_line None, brace_count 0
# 19367 line error - start line None, end_line None, brace_count 0
# 19368 line error - start line None, end_line None, brace_count 0
# 19369 line error - start line None, end_line None, brace_count 0
# 19427 line error - start line 19, end_line None, brace_count 1
# 19434 line error - start line 6, end_line None, brace_count 1
# 19565 line error - start line 3, end_line None, brace_count 1
# 19568 line error - start line 5, end_line None, brace_count 1
# 19630 line error - start line 10, end_line None, brace_count 1
# 19762 line error - start line None, end_line None, brace_count 0
# 19763 line error - start line None, end_line None, brace_count 0
# 19765 line error - start line None, end_line None, brace_count 0
# 19766 line error - start line None, end_line None, brace_count 0
# 19767 line error - start line None, end_line None, brace_count 0
# 19769 line error - start line None, end_line None, brace_count 0
# 19832 line error - start line 4, end_line None, brace_count 1
# 19850 line error - start line 3, end_line None, brace_count 1
# 19876 line error - start line 3, end_line None, brace_count 1
# 19920 line error - start line 3, end_line None, brace_count 1
# 19979 line error - start line 3, end_line None, brace_count 1
# 20070 line error - start line 12, end_line None, brace_count 1
# 20152 line error - start line None, end_line None, brace_count 0
# 20166 line error - start line None, end_line None, brace_count 0
# 20167 line error - start line None, end_line None, brace_count 0
# 20187 line error - start line None, end_line None, brace_count 0
# 20531 line error - start line 44, end_line None, brace_count 1
# 20629 line error - start line 3, end_line None, brace_count 1
# 20771 line error - start line 5, end_line None, brace_count 1
# 20885 line error - start line 3, end_line None, brace_count 1
# 20939 line error - start line 4, end_line None, brace_count 1
# 20959 line error - start line 2, end_line None, brace_count 1
# 20983 line error - start line None, end_line None, brace_count 0
# 21018 line error - start line 6, end_line None, brace_count 1
# 21198 line error - start line 8, end_line None, brace_count 1
# 21241 line error - start line 13, end_line None, brace_count 1
# 21267 line error - start line 7, end_line None, brace_count 1
# 21279 line error - start line 5, end_line None, brace_count 1
# 21358 line error - start line 5, end_line None, brace_count 1
# 21375 line error - start line None, end_line None, brace_count 0
# 21376 line error - start line None, end_line None, brace_count 0
# 21379 line error - start line None, end_line None, brace_count 0
# 21380 line error - start line None, end_line None, brace_count 0
# 21381 line error - start line None, end_line None, brace_count 0
# 21832 line error - start line 4, end_line None, brace_count 1
# 21842 line error - start line None, end_line None, brace_count 0
# 21857 line error - start line None, end_line None, brace_count 0
# 21859 line error - start line None, end_line None, brace_count 0
# 21862 line error - start line None, end_line None, brace_count 0
# 21865 line error - start line None, end_line None, brace_count 0
# 21868 line error - start line 75, end_line None, brace_count 1
# 21876 line error - start line 21, end_line None, brace_count 1
# 21890 line error - start line 18, end_line None, brace_count 2
# 21938 line error - start line 2, end_line None, brace_count 2
# 22260 line error - start line 5, end_line None, brace_count 1
# 22292 line error - start line None, end_line None, brace_count 0
# 22296 line error - start line None, end_line None, brace_count 0
# 22297 line error - start line None, end_line None, brace_count 0
# 22298 line error - start line None, end_line None, brace_count 0
# 22299 line error - start line None, end_line None, brace_count 0
# 22300 line error - start line None, end_line None, brace_count 0
# 22301 line error - start line None, end_line None, brace_count 0
# 22493 line error - start line 34, end_line None, brace_count 1
# 22494 line error - start line 4, end_line None, brace_count 1
# 22645 line error - start line 3, end_line None, brace_count 1
# 22689 line error - start line None, end_line None, brace_count 0
# 22690 line error - start line None, end_line None, brace_count 0
# 22691 line error - start line None, end_line None, brace_count 0
# 22695 line error - start line None, end_line None, brace_count 0
# 22698 line error - start line None, end_line None, brace_count 0
# 22702 line error - start line 4, end_line None, brace_count 1
# 22703 line error - start line 2, end_line None, brace_count 1
# 22765 line error - start line 15, end_line None, brace_count 1
# 22896 line error - start line 7, end_line None, brace_count 1
# 22897 line error - start line 7, end_line None, brace_count 1
# 22914 line error - start line 5, end_line None, brace_count 1
# 22967 line error - start line 17, end_line None, brace_count 1
# 22980 line error - start line 14, end_line None, brace_count 1
# 22985 line error - start line 3, end_line None, brace_count 1
# 23025 line error - start line 4, end_line None, brace_count 1
# 23037 line error - start line None, end_line None, brace_count 0
# 23038 line error - start line None, end_line None, brace_count 0
# 23042 line error - start line None, end_line None, brace_count 0
# 23043 line error - start line None, end_line None, brace_count 0
# 23058 line error - start line None, end_line None, brace_count 0
# 23059 line error - start line None, end_line None, brace_count 0
# 23065 line error - start line 30, end_line None, brace_count 1
# 23339 line error - start line 27, end_line None, brace_count 1
# 23379 line error - start line None, end_line None, brace_count 0
# 23384 line error - start line None, end_line None, brace_count 0
# 23387 line error - start line None, end_line None, brace_count 0
# 23605 line error - start line 3, end_line None, brace_count 1
# 23619 line error - start line 8, end_line None, brace_count 1
# 23620 line error - start line 23, end_line None, brace_count 1
# 23740 line error - start line 7, end_line None, brace_count 1
# 23749 line error - start line None, end_line None, brace_count 0
# 23755 line error - start line None, end_line None, brace_count 0
# 23757 line error - start line None, end_line None, brace_count 0
# 23758 line error - start line None, end_line None, brace_count 0
# 23759 line error - start line None, end_line None, brace_count 0
# 23778 line error - start line None, end_line None, brace_count 0
# 23827 line error - start line 3, end_line None, brace_count 2
# 23853 line error - start line 11, end_line None, brace_count 1
# 23893 line error - start line 3, end_line None, brace_count 1
# 23902 line error - start line 3, end_line None, brace_count 1
# 23915 line error - start line 17, end_line None, brace_count 1
# 24054 line error - start line 27, end_line None, brace_count 1
# 24165 line error - start line 25, end_line None, brace_count 1
# 24215 line error - start line None, end_line None, brace_count 0
# 24225 line error - start line None, end_line None, brace_count 0
# 24421 line error - start line 3, end_line None, brace_count 2
# 24509 line error - start line 3, end_line None, brace_count 1
# 24510 line error - start line 22, end_line None, brace_count 1
# 24548 line error - start line 26, end_line None, brace_count 1
# 24552 line error - start line 5, end_line None, brace_count 1
# 24554 line error - start line 5, end_line None, brace_count 1
# 24555 line error - start line 4, end_line None, brace_count 1
# 24703 line error - start line None, end_line None, brace_count 0
# 24704 line error - start line None, end_line None, brace_count 0
# 24786 line error - start line 22, end_line None, brace_count 1
# 24962 line error - start line 7, end_line None, brace_count 1
# 25068 line error - start line 42, end_line None, brace_count 1
# 25138 line error - start line None, end_line None, brace_count 0
# 25140 line error - start line None, end_line None, brace_count 0
# 25141 line error - start line None, end_line None, brace_count 0
# 25149 line error - start line None, end_line None, brace_count 0
# 25159 line error - start line None, end_line None, brace_count 0
# 25160 line error - start line None, end_line None, brace_count 0
# 25161 line error - start line None, end_line None, brace_count 0
# 25162 line error - start line None, end_line None, brace_count 0
# 25168 line error - start line None, end_line None, brace_count 0
# 25169 line error - start line None, end_line None, brace_count 0
# 25184 line error - start line 9, end_line None, brace_count 1
# 25218 line error - start line 3, end_line None, brace_count 1
# 25221 line error - start line 10, end_line None, brace_count 1
# 25223 line error - start line 40, end_line None, brace_count 1
# 25415 line error - start line 8, end_line None, brace_count 1
# 25466 line error - start line 5, end_line None, brace_count 1
# 25513 line error - start line 5, end_line None, brace_count 2
# 25514 line error - start line 4, end_line None, brace_count 2
# 25522 line error - start line None, end_line None, brace_count 0
# 25562 line error - start line None, end_line None, brace_count 0
# 25577 line error - start line None, end_line None, brace_count 0
# 25578 line error - start line None, end_line None, brace_count 0
# 25579 line error - start line None, end_line None, brace_count 0
# 25582 line error - start line None, end_line None, brace_count 0
# 25583 line error - start line None, end_line None, brace_count 0
# 25590 line error - start line 4, end_line None, brace_count 1
# 25596 line error - start line 22, end_line None, brace_count 1
# 25940 line error - start line 7, end_line None, brace_count 1
# 25941 line error - start line 3, end_line None, brace_count 1
# 25961 line error - start line None, end_line None, brace_count 0
# 25977 line error - start line None, end_line None, brace_count 0
# 26039 line error - start line 29, end_line None, brace_count 1
# 26059 line error - start line 3, end_line None, brace_count 1
# 26267 line error - start line None, end_line None, brace_count 0
# 26300 line error - start line 3, end_line None, brace_count 1
# 26367 line error - start line 3, end_line None, brace_count 2
# 26372 line error - start line 12, end_line None, brace_count 1
# 26456 line error - start line 16, end_line None, brace_count 1
# 26478 line error - start line 3, end_line None, brace_count 1
# 26524 line error - start line 11, end_line None, brace_count 1
# 26629 line error - start line 20, end_line None, brace_count 1
# 26669 line error - start line 3, end_line None, brace_count 1
# 26703 line error - start line None, end_line None, brace_count 0
# 26844 line error - start line 4, end_line None, brace_count 1
# 26882 line error - start line 3, end_line None, brace_count 1
# 26988 line error - start line 4, end_line None, brace_count 1
# 27032 line error - start line 24, end_line None, brace_count 1
# 27312 line error - start line 9, end_line None, brace_count 1
# 27319 line error - start line 34, end_line None, brace_count 1
# 27499 line error - start line 2, end_line None, brace_count 1
# 27501 line error - start line 67, end_line None, brace_count 1
# 27502 line error - start line 3, end_line None, brace_count 1
# 27524 line error - start line 6, end_line None, brace_count 1
# 27559 line error - start line 3, end_line None, brace_count 1
# 27570 line error - start line None, end_line None, brace_count 0
# 27571 line error - start line None, end_line None, brace_count 0
# 27575 line error - start line None, end_line None, brace_count 0
# 27580 line error - start line None, end_line None, brace_count 0
# 27585 line error - start line None, end_line None, brace_count 0
# 27586 line error - start line 5, end_line None, brace_count 1
# 27598 line error - start line None, end_line None, brace_count 0
# 27684 line error - start line 40, end_line None, brace_count 1
# 27691 line error - start line 3, end_line None, brace_count 1
# 27710 line error - start line 23, end_line None, brace_count 2
# 27736 line error - start line 3, end_line None, brace_count 2
# 27742 line error - start line 3, end_line None, brace_count 1
# 27744 line error - start line 4, end_line None, brace_count 2
# 27854 line error - start line 3, end_line None, brace_count 1
# 27867 line error - start line 30, end_line None, brace_count 1
# 27938 line error - start line 25, end_line None, brace_count 1
# 28031 line error - start line 3, end_line None, brace_count 1
# 28042 line error - start line 19, end_line None, brace_count 1
# 28051 line error - start line None, end_line None, brace_count 0
# 28052 line error - start line None, end_line None, brace_count 0
# 28053 line error - start line None, end_line None, brace_count 0
# 28056 line error - start line None, end_line None, brace_count 0
# 28057 line error - start line None, end_line None, brace_count 0
# 28062 line error - start line None, end_line None, brace_count 0
# 28063 line error - start line None, end_line None, brace_count 0
# 28064 line error - start line None, end_line None, brace_count 0
# 28072 line error - start line None, end_line None, brace_count 0
# 28077 line error - start line None, end_line None, brace_count 0
# 28106 line error - start line None, end_line None, brace_count 0
# 28107 line error - start line None, end_line None, brace_count 0
# 28112 line error - start line 3, end_line None, brace_count 1
# 28116 line error - start line None, end_line None, brace_count 0
# 28118 line error - start line 3, end_line None, brace_count 1
# 28130 line error - start line None, end_line None, brace_count 0
# 28305 line error - start line 3, end_line None, brace_count 1
# 28395 line error - start line 23, end_line None, brace_count 1
# 28398 line error - start line 4, end_line None, brace_count 1
# 28414 line error - start line 4, end_line None, brace_count 1
# 28462 line error - start line None, end_line None, brace_count 0
# 28475 line error - start line None, end_line None, brace_count 0
# 28485 line error - start line None, end_line None, brace_count 0
# 28488 line error - start line None, end_line None, brace_count 0
# 28572 line error - start line 3, end_line None, brace_count 1
# 28645 line error - start line 2, end_line None, brace_count 1
# 28780 line error - start line 3, end_line None, brace_count 1
# 28805 line error - start line 3, end_line None, brace_count 1
# 28849 line error - start line 10, end_line None, brace_count 1
# 28967 line error - start line None, end_line None, brace_count 0
# 28972 line error - start line None, end_line None, brace_count 0
# 28973 line error - start line None, end_line None, brace_count 0
# 28987 line error - start line 2, end_line None, brace_count 1
# 28993 line error - start line 4, end_line None, brace_count 1
# 29020 line error - start line 3, end_line None, brace_count 1
# 29152 line error - start line 6, end_line None, brace_count 1
# 29298 line error - start line 23, end_line None, brace_count 1
# 29356 line error - start line None, end_line None, brace_count 0
# 29856 line error - start line 3, end_line None, brace_count 1
# 29870 line error - start line None, end_line None, brace_count 0
# 29871 line error - start line None, end_line None, brace_count 0
# 29872 line error - start line None, end_line None, brace_count 0
# 29873 line error - start line None, end_line None, brace_count 0
# 29874 line error - start line None, end_line None, brace_count 0
# 29875 line error - start line None, end_line None, brace_count 0
# 29880 line error - start line None, end_line None, brace_count 0
# 29881 line error - start line None, end_line None, brace_count 0
# 29882 line error - start line None, end_line None, brace_count 0
# 30066 line error - start line 14, end_line None, brace_count 1
# 30085 line error - start line 7, end_line None, brace_count 1
# 30232 line error - start line 6, end_line None, brace_count 1
# 30234 line error - start line 3, end_line None, brace_count 1
# 30291 line error - start line None, end_line None, brace_count 0
# 30302 line error - start line None, end_line None, brace_count 0
# 30304 line error - start line None, end_line None, brace_count 0
# 30305 line error - start line None, end_line None, brace_count 0
# 30346 line error - start line None, end_line None, brace_count 0
# 30366 line error - start line 46, end_line None, brace_count 1
# 30621 line error - start line 21, end_line None, brace_count 1
# 30681 line error - start line 3, end_line None, brace_count 2
# 30683 line error - start line 3, end_line None, brace_count 1
# 30738 line error - start line 6, end_line None, brace_count 1
# 30745 line error - start line 3, end_line None, brace_count 1
# 30806 line error - start line 16, end_line None, brace_count 1
# 31041 line error - start line 15, end_line None, brace_count 1
# 31133 line error - start line None, end_line None, brace_count 0
# 31146 line error - start line 5, end_line None, brace_count 1
# 31212 line error - start line 28, end_line None, brace_count 1
# 31258 line error - start line 3, end_line None, brace_count 2
# 31263 line error - start line 19, end_line None, brace_count 1
# 31598 line error - start line None, end_line None, brace_count 0
# 31612 line error - start line None, end_line None, brace_count 0
# 31617 line error - start line 21, end_line None, brace_count 1
# 31650 line error - start line 21, end_line None, brace_count 1
# 31673 line error - start line 35, end_line None, brace_count 1
# 31680 line error - start line 27, end_line None, brace_count 1
# 31699 line error - start line 12, end_line None, brace_count 1
# 31703 line error - start line 7, end_line None, brace_count 1
# 31798 line error - start line 8, end_line None, brace_count 1
# 31927 line error - start line 2, end_line None, brace_count 1
# 31989 line error - start line None, end_line None, brace_count 0
# 32003 line error - start line None, end_line None, brace_count 0
# 32107 line error - start line 3, end_line None, brace_count 1
# 32215 line error - start line 3, end_line None, brace_count 2
# 32343 line error - start line 4, end_line None, brace_count 1
# 32374 line error - start line 7, end_line None, brace_count 1
# 32476 line error - start line 3, end_line None, brace_count 1
# 32556 line error - start line 23, end_line None, brace_count 1
# 32638 line error - start line 5, end_line None, brace_count 1
# 32640 line error - start line 43, end_line None, brace_count 1
# 32703 line error - start line 5, end_line None, brace_count 1
# 32763 line error - start line 3, end_line None, brace_count 1
# 32909 line error - start line 4, end_line None, brace_count 1
# 33130 line error - start line 24, end_line None, brace_count 2
# 33220 line error - start line 3, end_line None, brace_count 1
# 33244 line error - start line None, end_line None, brace_count 0
# 33254 line error - start line None, end_line None, brace_count 0
# 33255 line error - start line None, end_line None, brace_count 0
# 33256 line error - start line None, end_line None, brace_count 0
# 33257 line error - start line None, end_line None, brace_count 0
# 33258 line error - start line None, end_line None, brace_count 0
# 33259 line error - start line None, end_line None, brace_count 0
# 33292 line error - start line None, end_line None, brace_count 0
# 33293 line error - start line None, end_line None, brace_count 0
# 33300 line error - start line None, end_line None, brace_count 0
# 33301 line error - start line None, end_line None, brace_count 0
# 33302 line error - start line None, end_line None, brace_count 0
# 33303 line error - start line None, end_line None, brace_count 0
# 33304 line error - start line None, end_line None, brace_count 0
# 33305 line error - start line None, end_line None, brace_count 0
# 33306 line error - start line None, end_line None, brace_count 0
# 33307 line error - start line None, end_line None, brace_count 0
# 33308 line error - start line None, end_line None, brace_count 0
# 33324 line error - start line None, end_line None, brace_count 0
# 33373 line error - start line 8, end_line None, brace_count 1
# 33374 line error - start line 7, end_line None, brace_count 1
# 33375 line error - start line 15, end_line None, brace_count 1
# 33376 line error - start line 15, end_line None, brace_count 1
# 33377 line error - start line 7, end_line None, brace_count 1
# 33380 line error - start line 24, end_line None, brace_count 1
# 33397 line error - start line 27, end_line None, brace_count 1
# 33419 line error - start line 3, end_line None, brace_count 1
# 33454 line error - start line 13, end_line None, brace_count 1
# 33592 line error - start line 3, end_line None, brace_count 1
# 33597 line error - start line 6, end_line None, brace_count 1
# 33606 line error - start line 4, end_line None, brace_count 1
# 33757 line error - start line None, end_line None, brace_count 0
# 33773 line error - start line None, end_line None, brace_count 0
# 33774 line error - start line None, end_line None, brace_count 0
# 33835 line error - start line 67, end_line None, brace_count 1
# 33924 line error - start line 3, end_line None, brace_count 2
# 34038 line error - start line 3, end_line None, brace_count 1
# 34039 line error - start line 41, end_line None, brace_count 1
# 34043 line error - start line 10, end_line None, brace_count 1
# 34044 line error - start line 14, end_line None, brace_count 1
# 34049 line error - start line 3, end_line None, brace_count 1
# 34050 line error - start line 52, end_line None, brace_count 1
# 34051 line error - start line 3, end_line None, brace_count 1
# 34052 line error - start line 73, end_line None, brace_count 1
# 34054 line error - start line 47, end_line None, brace_count 1
# 34059 line error - start line 3, end_line None, brace_count 1
# 34061 line error - start line 4, end_line None, brace_count 1
# 34062 line error - start line 3, end_line None, brace_count 1
# 34064 line error - start line 3, end_line None, brace_count 1
# 34067 line error - start line 5, end_line None, brace_count 1
# 34072 line error - start line 3, end_line None, brace_count 1
# 34075 line error - start line 5, end_line None, brace_count 1
# 34111 line error - start line 24, end_line None, brace_count 1
# 34215 line error - start line None, end_line None, brace_count 0
# 34227 line error - start line None, end_line None, brace_count 0
# 34230 line error - start line None, end_line None, brace_count 0
# 34253 line error - start line 3, end_line None, brace_count 1
# 34358 line error - start line 14, end_line None, brace_count 1
# 34659 line error - start line 4, end_line None, brace_count 1
# 34922 line error - start line 2, end_line None, brace_count 1
# 34928 line error - start line 3, end_line None, brace_count 1
# 35089 line error - start line None, end_line None, brace_count 0
# 35099 line error - start line None, end_line None, brace_count 0
# 35101 line error - start line None, end_line None, brace_count 0
# ...
# 48029 line error - start line 25, end_line None, brace_count 1
# 48033 line error - start line 37, end_line None, brace_count 1
# 48165 line error - start line 26, end_line None, brace_count 1
# 48168 line error - start line 27, end_line None, brace_count 1
# 48249 line error - start line 3, end_line None, brace_count 1
# 48323 line error - start line 16, end_line None, brace_count 1
# 48338 line error - start line None, end_line None, brace_count 0
# 48340 line error - start line None, end_line None, brace_count 0
# 48351 line error - start line None, end_line None, brace_count 0
# 48353 line error - start line None, end_line None, brace_count 0
# 48354 line error - start line None, end_line None, brace_count 0
# 48355 line error - start line None, end_line None, brace_count 0
# 48358 line error - start line None, end_line None, brace_count 0
# 48359 line error - start line None, end_line None, brace_count 0
# 48368 line error - start line None, end_line None, brace_count 0
# 48536 line error - start line 5, end_line None, brace_count 1
# 48537 line error - start line 5, end_line None, brace_count 1
# 48551 line error - start line 27, end_line None, brace_count 1
# 48680 line error - start line 3, end_line None, brace_count 1
# 48682 line error - start line 4, end_line None, brace_count 1
# 48757 line error - start line None, end_line None, brace_count 0
# 48758 line error - start line None, end_line None, brace_count 0
# 48759 line error - start line None, end_line None, brace_count 0
# 48760 line error - start line None, end_line None, brace_count 0
# 48766 line error - start line None, end_line None, brace_count 0
# 48774 line error - start line None, end_line None, brace_count 0
# 48832 line error - start line 74, end_line None, brace_count 1
# 48833 line error - start line 21, end_line None, brace_count 1
# 48873 line error - start line 20, end_line None, brace_count 1
# 48909 line error - start line 2, end_line None, brace_count 1
# 48966 line error - start line 13, end_line None, brace_count 1
# 49065 line error - start line 48, end_line None, brace_count 1
# 49126 line error - start line None, end_line None, brace_count 0
# 49145 line error - start line None, end_line None, brace_count 0
# 49146 line error - start line None, end_line None, brace_count 0
# 49147 line error - start line None, end_line None, brace_count 0
# 49154 line error - start line 2, end_line None, brace_count 1
# 49155 line error - start line None, end_line None, brace_count 0
# 49156 line error - start line None, end_line None, brace_count 0
# 49187 line error - start line 9, end_line None, brace_count 1
# 49364 line error - start line 5, end_line None, brace_count 1
# 49452 line error - start line 3, end_line None, brace_count 1
# 49474 line error - start line 11, end_line None, brace_count 1
# 49668 line error - start line 3, end_line None, brace_count 1
# 50018 line error - start line None, end_line None, brace_count 0
# 50021 line error - start line None, end_line None, brace_count 0
# 50113 line error - start line 3, end_line None, brace_count 1
# 50127 line error - start line 3, end_line None, brace_count 1
# 50185 line error - start line 5, end_line None, brace_count 1
# 50488 line error - start line None, end_line None, brace_count 0
# 50522 line error - start line None, end_line None, brace_count 0
# 50523 line error - start line None, end_line None, brace_count 0
# 50538 line error - start line 3, end_line None, brace_count 1
# 50588 line error - start line 3, end_line None, brace_count 1
# 50656 line error - start line 7, end_line None, brace_count 1
# 50754 line error - start line 16, end_line None, brace_count 1
# 50865 line error - start line 3, end_line None, brace_count 2
# 50874 line error - start line 2, end_line None, brace_count 1
# 50920 line error - start line None, end_line None, brace_count 0
# 50921 line error - start line None, end_line None, brace_count 0
# 51185 line error - start line 6, end_line None, brace_count 1
# 51227 line error - start line None, end_line None, brace_count 0
# 51228 line error - start line None, end_line None, brace_count 0
# 51253 line error - start line 3, end_line None, brace_count 1
# 51344 line error - start line 4, end_line None, brace_count 1
# 51413 line error - start line 7, end_line None, brace_count 1
# 51548 line error - start line 3, end_line None, brace_count 1
# 51579 line error - start line 17, end_line None, brace_count 1
# 51580 line error - start line 17, end_line None, brace_count 1
# 51689 line error - start line None, end_line None, brace_count 0
# 51730 line error - start line None, end_line None, brace_count 0
# 51731 line error - start line None, end_line None, brace_count 0
# 51738 line error - start line None, end_line None, brace_count 0
# 51746 line error - start line 42, end_line None, brace_count 1
# 51774 line error - start line 3, end_line None, brace_count 1
# 51810 line error - start line 5, end_line None, brace_count 1
# 51851 line error - start line 12, end_line None, brace_count 1
# 51974 line error - start line 3, end_line None, brace_count 1
# 52007 line error - start line 11, end_line None, brace_count 1
# 52047 line error - start line 15, end_line None, brace_count 1
# 52101 line error - start line 3, end_line None, brace_count 1
# 52106 line error - start line None, end_line None, brace_count 0
# 52113 line error - start line None, end_line None, brace_count 0
# 52119 line error - start line None, end_line None, brace_count 0
# 52124 line error - start line None, end_line None, brace_count 0
# 52129 line error - start line None, end_line None, brace_count 0
# 52166 line error - start line 9, end_line None, brace_count 1
# 52214 line error - start line 3, end_line None, brace_count 1
# 52215 line error - start line 2, end_line None, brace_count 1
# 52216 line error - start line 2, end_line None, brace_count 1
# 52236 line error - start line 3, end_line None, brace_count 2
# 52442 line error - start line 26, end_line None, brace_count 1
# 52489 line error - start line None, end_line None, brace_count 0
# 52510 line error - start line None, end_line None, brace_count 0
# 52511 line error - start line None, end_line None, brace_count 0
# 52512 line error - start line None, end_line None, brace_count 0
# 52513 line error - start line None, end_line None, brace_count 0
# 52514 line error - start line None, end_line None, brace_count 0
# 52515 line error - start line None, end_line None, brace_count 0
# 52516 line error - start line None, end_line None, brace_count 0
# 52518 line error - start line None, end_line None, brace_count 0
# 52519 line error - start line None, end_line None, brace_count 0
# 52520 line error - start line None, end_line None, brace_count 0
# 52521 line error - start line None, end_line None, brace_count 0
# 52522 line error - start line None, end_line None, brace_count 0
# 52523 line error - start line None, end_line None, brace_count 0
# 52524 line error - start line None, end_line None, brace_count 0
# 52525 line error - start line None, end_line None, brace_count 0
# 52533 line error - start line None, end_line None, brace_count 0
# 52534 line error - start line None, end_line None, brace_count 0
# 52535 line error - start line None, end_line None, brace_count 0
# 52536 line error - start line None, end_line None, brace_count 0
# 52537 line error - start line None, end_line None, brace_count 0
# 52538 line error - start line None, end_line None, brace_count 0
# 52539 line error - start line None, end_line None, brace_count 0
# 52540 line error - start line None, end_line None, brace_count 0
# 52541 line error - start line None, end_line None, brace_count 0
# 52542 line error - start line None, end_line None, brace_count 0
# 52543 line error - start line None, end_line None, brace_count 0
# 52544 line error - start line None, end_line None, brace_count 0
# 52545 line error - start line None, end_line None, brace_count 0
# 52546 line error - start line None, end_line None, brace_count 0
# 52547 line error - start line None, end_line None, brace_count 0
# 52548 line error - start line None, end_line None, brace_count 0
# 52549 line error - start line None, end_line None, brace_count 0
# 52550 line error - start line None, end_line None, brace_count 0
# 52551 line error - start line None, end_line None, brace_count 0
# 52552 line error - start line None, end_line None, brace_count 0
# 52553 line error - start line None, end_line None, brace_count 0
# 52554 line error - start line None, end_line None, brace_count 0
# 52558 line error - start line None, end_line None, brace_count 0
# 52559 line error - start line None, end_line None, brace_count 0
# 52560 line error - start line None, end_line None, brace_count 0
# 52561 line error - start line None, end_line None, brace_count 0
# 52562 line error - start line None, end_line None, brace_count 0
# 52563 line error - start line None, end_line None, brace_count 0
# 52564 line error - start line None, end_line None, brace_count 0
# 52575 line error - start line None, end_line None, brace_count 0
# 52576 line error - start line None, end_line None, brace_count 0
# 52577 line error - start line None, end_line None, brace_count 0
# 52578 line error - start line None, end_line None, brace_count 0
# 52579 line error - start line None, end_line None, brace_count 0
# 52580 line error - start line None, end_line None, brace_count 0
# 52581 line error - start line None, end_line None, brace_count 0
# 52582 line error - start line None, end_line None, brace_count 0
# 52583 line error - start line None, end_line None, brace_count 0
# 52584 line error - start line None, end_line None, brace_count 0
# 52585 line error - start line None, end_line None, brace_count 0
# 52586 line error - start line None, end_line None, brace_count 0
# 52587 line error - start line None, end_line None, brace_count 0
# 52588 line error - start line None, end_line None, brace_count 0
# 52589 line error - start line None, end_line None, brace_count 0
# 52590 line error - start line None, end_line None, brace_count 0
# 52591 line error - start line None, end_line None, brace_count 0
# 52592 line error - start line None, end_line None, brace_count 0
# 52616 line error - start line None, end_line None, brace_count 0
# 52617 line error - start line None, end_line None, brace_count 0
# 52618 line error - start line None, end_line None, brace_count 0
# 52619 line error - start line None, end_line None, brace_count 0
# 52627 line error - start line None, end_line None, brace_count 0
# 52701 line error - start line 6, end_line None, brace_count 1
# 52746 line error - start line 3, end_line None, brace_count 1
# 52827 line error - start line 7, end_line None, brace_count 1
# 53135 line error - start line 8, end_line None, brace_count 1
# 53177 line error - start line 6, end_line None, brace_count 1
# 53264 line error - start line 14, end_line None, brace_count 1
# 53483 line error - start line 5, end_line None, brace_count 1
# 53723 line error - start line 16, end_line None, brace_count 1
# 53955 line error - start line None, end_line None, brace_count 0
# 54065 line error - start line 3, end_line None, brace_count 1
# 54104 line error - start line 5, end_line None, brace_count 1
# 54145 line error - start line 3, end_line None, brace_count 1
# 54159 line error - start line 3, end_line None, brace_count 1
# 54163 line error - start line 3, end_line None, brace_count 1
# 54179 line error - start line 32, end_line None, brace_count 1
# 54330 line error - start line None, end_line None, brace_count 0
# 54331 line error - start line None, end_line None, brace_count 0
# 54332 line error - start line None, end_line None, brace_count 0
# 54333 line error - start line None, end_line None, brace_count 0
# 54334 line error - start line None, end_line None, brace_count 0
# 54335 line error - start line None, end_line None, brace_count 0
# 54336 line error - start line None, end_line None, brace_count 0
# 54337 line error - start line None, end_line None, brace_count 0
# 54338 line error - start line None, end_line None, brace_count 0
# 54349 line error - start line None, end_line None, brace_count 0
# 54352 line error - start line None, end_line None, brace_count 0
# 54367 line error - start line 55, end_line None, brace_count 1
# 54368 line error - start line 55, end_line None, brace_count 1
# 54424 line error - start line 79, end_line None, brace_count 1
# 54459 line error - start line 19, end_line None, brace_count 1
# 54548 line error - start line 59, end_line None, brace_count 1
# 54551 line error - start line 3, end_line None, brace_count 1
# 54632 line error - start line 3, end_line None, brace_count 1
# 54684 line error - start line 26, end_line None, brace_count 1
# 54715 line error - start line None, end_line None, brace_count 0
# 54721 line error - start line None, end_line None, brace_count 0
# 54740 line error - start line 3, end_line None, brace_count 1
# 54799 line error - start line 3, end_line None, brace_count 1
# 54880 line error - start line 5, end_line None, brace_count 1
# 55086 line error - start line 37, end_line None, brace_count 1
# 55091 line error - start line None, end_line None, brace_count 0
# 55100 line error - start line None, end_line None, brace_count 0
# 55101 line error - start line None, end_line None, brace_count 0
# 55110 line error - start line None, end_line None, brace_count 0
# 55118 line error - start line None, end_line None, brace_count 0
# 55120 line error - start line None, end_line None, brace_count 0
# 55121 line error - start line None, end_line None, brace_count 0
# 55122 line error - start line None, end_line None, brace_count 0
# 55123 line error - start line None, end_line None, brace_count 0
# 55125 line error - start line None, end_line None, brace_count 0
# 55126 line error - start line None, end_line None, brace_count 0
# 55127 line error - start line None, end_line None, brace_count 0
# 55128 line error - start line None, end_line None, brace_count 0
# 55135 line error - start line None, end_line None, brace_count 0
# 55143 line error - start line None, end_line None, brace_count 0
# 55144 line error - start line None, end_line None, brace_count 0
# 55145 line error - start line None, end_line None, brace_count 0
# 55146 line error - start line None, end_line None, brace_count 0
# 55147 line error - start line None, end_line None, brace_count 0
# 55151 line error - start line None, end_line None, brace_count 0
# 55153 line error - start line None, end_line None, brace_count 0
# 55225 line error - start line 18, end_line None, brace_count 1
# 55227 line error - start line 18, end_line None, brace_count 1
# 55260 line error - start line 5, end_line None, brace_count 1
# 55292 line error - start line 66, end_line None, brace_count 1
# 55296 line error - start line 15, end_line None, brace_count 1
# 55319 line error - start line 3, end_line None, brace_count 1
# 55388 line error - start line 37, end_line None, brace_count 1
# 55587 line error - start line None, end_line None, brace_count 0
# 55606 line error - start line None, end_line None, brace_count 0
# 55607 line error - start line None, end_line None, brace_count 0
# 55608 line error - start line None, end_line None, brace_count 0
# 55616 line error - start line None, end_line None, brace_count 0
# 55617 line error - start line None, end_line None, brace_count 0
# 55618 line error - start line None, end_line None, brace_count 0
# 55619 line error - start line None, end_line None, brace_count 0
# 55620 line error - start line None, end_line None, brace_count 0
# 55624 line error - start line None, end_line None, brace_count 0
# 55727 line error - start line 3, end_line None, brace_count 1
# 55730 line error - start line 11, end_line None, brace_count 1
# 55738 line error - start line 4, end_line None, brace_count 1
# 55836 line error - start line 15, end_line None, brace_count 1
# 55890 line error - start line 6, end_line None, brace_count 1
# 55917 line error - start line 5, end_line None, brace_count 1
# 55976 line error - start line 68, end_line None, brace_count 1
# 56028 line error - start line None, end_line None, brace_count 0
# 56029 line error - start line None, end_line None, brace_count 0
# 56030 line error - start line None, end_line None, brace_count 0
# 56039 line error - start line None, end_line None, brace_count 0
# 오류 code 개수 : 1343

# %%
function_error_count = 0
main_error_count = 0
for i in range(len(target_line_numbers)):
    if main_loc_list[i][0] == main_loc_list[i][1] == -1:
        continue
    elif (main_loc_list[i][0] <= target_line_numbers[i]) & (target_line_numbers[i] <= main_loc_list[i][1]):
        main_error_count += 1
    else:
        function_error_count += 1
print(f'main error = {main_error_count}\nfunction error = {function_error_count}')
print(f'total sum = {main_error_count + function_error_count}')
# Out:
# main error = 39057
# function error = 16916
# total sum = 55973

# %%
function_error_count_modified = 0
main_error_count_modified = 0
for i in range(len(target_line_numbers)):
    if main_loc_list_modified[i][0] == main_loc_list_modified[i][1] == -1:
        continue
    elif (main_loc_list_modified[i][0] <= target_line_numbers[i]) & (target_line_numbers[i] <= main_loc_list_modified[i][1]):
        main_error_count_modified += 1
    else:
        function_error_count_modified += 1
print(f'main error = {main_error_count_modified}\nfunction error = {function_error_count_modified}')
print(f'total sum = {main_error_count_modified + function_error_count_modified}')
# Out:
# main error = 37813
# function error = 16895
# total sum = 54708

# %%
import os

cpp_file_path = '/content/drive/MyDrive/logicalErrorFix-2/model/cpp'

cpp_gold_path = os.path.join(cpp_file_path, 'cpp_gold')
cpp_output_path = os.path.join(cpp_file_path, 'cpp_output')
cpp_source_path = os.path.join(cpp_file_path, 'cpp_source')

# %%
from tqdm import tqdm

def cpp_file_create(file_path, dictionary_list, str):
  for index, dictionary in tqdm(enumerate(dictionary_list)):
    with open(os.path.join(file_path, f'{str}_{index}.cpp'), 'w') as f:
      for key, value in dictionary.items():
        f.write(value + '\n')
    if index == 1000:
      break

# %%
print(target_code_dict_list[0])
# Out:
# {1: '#include <bits/stdc++.h>', 2: 'using namespace std;', 3: 'int ara[500008];', 4: 'set<int> s;', 5: 'set<int>::iterator it;', 6: 'int n;', 7: 'void check(int num) {', 8: 'for (int i = 1; i < n; i++) {', 9: 'if (!(ara[i] % num == 0 || ara[n + i] % num == 0)) {', 10: 'return;', 11: '}', 12: '}', 13: 'cout << num << endl;', 14: 'exit(0);', 15: '}', 16: 'int primefactor(int num) {', 17: 'int i;', 18: 'for (i = 2; i <= num / i; i++) {', 19: 'bool flag = 0;', 20: 'while (num % i == 0) {', 21: 'num /= i;', 22: 'if (!flag) {', 23: 'check(i);', 24: '}', 25: 'flag = 1;', 26: '}', 27: '}', 28: 'if (num > 1) {', 29: 'check(num);', 30: '}', 31: '}', 32: 'int main() {', 33: 'scanf("%d", &n);', 34: 'for (int i = 0; i < n; i++) {', 35: 'scanf("%d%d", &ara[i], &ara[n + i]);', 36: '}', 37: 'primefactor(ara[0]);', 38: 'primefactor(ara[n]);', 39: 'cout << "-1" << endl;', 40: 'return 0;', 41: '}'}

# %%
print(cpp_source_path)
# Out:
# /content/drive/MyDrive/logicalErrorFix-2/model/cpp/cpp_source

# %%
cpp_file_create(cpp_source_path, code_dict_list, 'source')
# Out:
# 1000it [00:10, 98.09it/s]

# %%
print(cpp_gold_path)
# Out:
# /content/drive/MyDrive/logicalErrorFix-2/model/cpp/cpp_gold

# %%
cpp_file_create(cpp_gold_path, target_code_dict_list, 'gold')
# Out:
# 1000it [00:10, 99.52it/s]
